# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/titanic_data_updated.csv')

# %% [markdown]
# ### 2. Analytical View of a Dataset

# %%
df.shape

print(f"Total Ptoential features: {df.shape[1]}")
print(f"Total Potential data: {df.shape[0]}")
# Out:
# Total Ptoential features: 12
# Total Potential data: 891

# %%
df.head(10)

df.sample(10)
# Out:
#      PassengerId Survived  Pclass                          Name     Sex   Age  \
# 747          748      yes  second         Sinkkonen, Miss. Anna  female  30.0
# 782          783       no   first        Long, Mr. Milton Clyde    male  29.0
# 136          137      yes   first  Newsom, Miss. Helen Monypeny  female  19.0
# 222          223       no   third       Green, Mr. George Henry    male  51.0
# 628          629       no   third     Bostandyeff, Mr. Guentcho    male  26.0
# 284          285       no   first    Smith, Mr. Richard William    male   NaN
# 744          745      yes   third            Stranden, Mr. Juho    male  31.0
# 250          251       no   third        Reed, Mr. James George    male   NaN
# 379          380       no   third   Gustafsson, Mr. Karl Gideon    male  19.0
# 179          180       no   third           Leonard, Mr. Lionel    male  36.0
#
#      SibSp  Parch             Ticket     Fare Cabin Embarked
# 747      0      0             250648  13.0000   NaN        S
# 782      0      0             113501  30.0000    D6        S
# 136      0      2              11752  26.2833   D47        S
# 222      0      0              21440   8.0500   NaN        S
# 628      0      0             349224   7.8958   NaN        S
# 284      0      0             113056  26.0000   A19        S
# 744      0      0  STON/O 2. 3101288   7.9250   NaN        S
# 250      0      0             362316   7.2500   NaN        S
# 379      0      0             347069   7.7750   NaN        S
# 179      0      0               LINE   0.0000   NaN        S

# %% [markdown]
# Feature Screening

# %% [markdown]
# ### 3. Feature Screening

# %%
# missing

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# checking duplicates
df.duplicated().sum()

df.drop_duplicates(inplace=True)

# %% [markdown]
# S

# %% [markdown]
# ### 4. Statistical Profiling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.699118    0.523008    0.381594   32.204208
# std     257.353842   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000   38.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# demo

# %% [markdown]
# ### 5. Univariate Analysis( Categorical Value Analysis -1 )

# %%
sns.countplot(data = df , x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
(df['Survived'].value_counts() / len(df)) * 100
# Out:
# Survived
# no     61.616162
# yes    38.383838
# Name: count, dtype: float64

# %%
sc = df['Survived'].value_counts()
sl = df['Survived'].unique()

plt.pie(sc,labels= sl,autopct="%1.1f")
plt.title('pie chart of survival rate')
plt.show()

# %% [markdown]
# ### 6. Univariate Analysis( Categorical Value Analysis -2)

# %%
sns.countplot(data =df , x=df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
(df['Pclass'].value_counts() /len(df)) * 100
# Out:
# Pclass
# third     55.106622
# first     24.242424
# second    20.650954
# Name: count, dtype: float64

# %%
sns.countplot(data = df , x=df['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
(df['Sex'].value_counts() / len(df) ) * 100
# Out:
# Sex
# male      64.758698
# female    35.241302
# Name: count, dtype: float64

# %%
sns.countplot(data = df , x=df['Embarked'])
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
(df['Embarked'].value_counts() / len(df) ) * 100
# Out:
# Embarked
# S    72.278339
# C    18.855219
# Q     8.641975
# Name: count, dtype: float64

# %% [markdown]
# demo

# %% [markdown]
# ### 7.Univariate Analysis ( Numerical Column Analysis - 1)

# %%
sns.histplot(df['Age'],bins=50)
plt.title('Histogram of Age')
plt.xlabel('Ages')
plt.ylabel('Frequeny')
plt.show()

# %%
sns.kdeplot(df['Age'])
plt.title('KDE plot of Age')
plt.xlabel('Ages')
plt.ylabel('probability distribution')
plt.show()

# %% [markdown]
# ### 8.Univariate Analysis ( Numerical Column Analysis - 2)

# %%
sns.histplot(df['Fare'],bins=50)
plt.title('Histogram of Fare')
plt.xlabel('Fare')
plt.ylabel('frequency')

plt.show()

# %%
sns.kdeplot(df['Fare'])
plt.title('KDE plot of Fare')
plt.xlabel('Fare')
plt.ylabel('probabilty distribution')

plt.show()

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>
